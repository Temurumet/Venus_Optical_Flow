# %%
import os
import shutil

def reorganize_for_raft(input_image_folder, input_flow_folder, output_folder):
    """
    Пересохраняет и переименовывает файлы, чтобы они соответствовали требованиям RAFT.

    Parameters:
    - input_image_folder: str, путь к папке с исходными изображениями.
    - input_flow_folder: str, путь к папке с исходными потоками.
    - output_folder: str, путь к папке, где будет создана структура RAFT.
    """
    # Создаём папки для изображений и потоков
    images_output_folder = os.path.join(output_folder, "images")
    flows_output_folder = os.path.join(output_folder, "flows")
    os.makedirs(images_output_folder, exist_ok=True)
    os.makedirs(flows_output_folder, exist_ok=True)

    # Список всех изображений
    image_files = sorted(os.listdir(input_image_folder))
    image_dict = {}
    for image_file in image_files:
        if image_file.endswith('.png'):
            parts = image_file.split('_')
            date, time = parts[1], parts[2]
            image_dict[f"{date}_{time}"] = image_file

    # Список всех потоков
    flow_files = sorted(os.listdir(input_flow_folder))

    for flow_file in flow_files:
        if not flow_file.endswith('.flo'):
            continue

        # Извлекаем информацию из имени потока
        date, time_1, time_2 = flow_file.replace('.flo', '').split('_')

        # Проверяем, что изображения существуют
        img1_name = image_dict.get(f"{date}_{time_1}")
        img2_name = image_dict.get(f"{date}_{time_2}")
        if not img1_name or not img2_name:
            print(f"Пропущены изображения для потока {flow_file}")
            continue

        # Путь к подпапке текущей пары
        pair_folder = os.path.join(images_output_folder, f"{date}_{time_1}_{time_2}")
        os.makedirs(pair_folder, exist_ok=True)

        # Копируем изображения в подпапку
        img1_path = os.path.join(input_image_folder, img1_name)
        img2_path = os.path.join(input_image_folder, img2_name)
        shutil.copy(img1_path, os.path.join(pair_folder, "img1.png"))
        shutil.copy(img2_path, os.path.join(pair_folder, "img2.png"))

        # Копируем поток в папку flows
        flow_src_path = os.path.join(input_flow_folder, flow_file)
        flow_dest_path = os.path.join(flows_output_folder, f"{date}_{time_1}_{time_2}.flo")
        # shutil.copy(flow_src_path, flow_dest_path)

        print(f"Обработана пара: {flow_file}, сохранено в {pair_folder}")

# Указание путей
input_image_folder = "/home/jupyter/datasphere/project/r0077-0078_png/small"  # Папка с исходными изображениями
input_flow_folder = "/home/jupyter/datasphere/project/Venus_dataset/flows"  # Папка с исходными потоками
output_folder = "Venus_dataset"  # Папка для сохранения в формате RAFT

# Запуск пересохранения
reorganize_for_raft(input_image_folder, input_flow_folder, output_folder)
# Out:
# Обработана пара: 20180331_080446_100445.flo, сохранено в Venus_dataset/images/20180331_080446_100445
# Обработана пара: 20180331_100445_120443.flo, сохранено в Venus_dataset/images/20180331_100445_120443
# Обработана пара: 20180331_140445_160444.flo, сохранено в Venus_dataset/images/20180331_140445_160444
# Обработана пара: 20180331_160444_180445.flo, сохранено в Venus_dataset/images/20180331_160444_180445
# Обработана пара: 20180331_180445_200444.flo, сохранено в Venus_dataset/images/20180331_180445_200444
# Обработана пара: 20180331_200444_220444.flo, сохранено в Venus_dataset/images/20180331_200444_220444
# Обработана пара: 20180401_100445_120444.flo, сохранено в Venus_dataset/images/20180401_100445_120444
# Обработана пара: 20180401_120444_140444.flo, сохранено в Venus_dataset/images/20180401_120444_140444
# Обработана пара: 20180401_140444_160445.flo, сохранено в Venus_dataset/images/20180401_140444_160445
# Обработана пара: 20180401_160445_180444.flo, сохранено в Venus_dataset/images/20180401_160445_180444
# Обработана пара: 20180401_180444_200444.flo, сохранено в Venus_dataset/images/20180401_180444_200444
# Обработана пара: 20180402_080445_100443.flo, сохранено в Venus_dataset/images/20180402_080445_100443
# Обработана пара: 20180402_100443_120444.flo, сохранено в Venus_dataset/images/20180402_100443_120444
# Обработана пара: 20180402_120444_140443.flo, сохранено в Venus_dataset/images/20180402_120444_140443
# Обработана пара: 20180402_140443_160443.flo, сохранено в Venus_dataset/images/20180402_140443_160443
# Обработана пара: 20180402_160443_180444.flo, сохранено в Venus_dataset/images/20180402_160443_180444
# Обработана пара: 20180402_180444_200443.flo, сохранено в Venus_dataset/images/20180402_180444_200443
# Обработана пара: 20180403_060443_080444.flo, сохранено в Venus_dataset/images/20180403_060443_080444
# Обработана пара: 20180403_080444_100445.flo, сохранено в Venus_dataset/images/20180403_080444_100445
# Обработана пара: 20180403_100445_120442.flo, сохранено в Venus_dataset/images/20180403_100445_120442
# Обработана пара: 20180403_120442_140445.flo, сохранено в Venus_dataset/images/20180403_120442_140445
# Обработана пара: 20180403_140445_160444.flo, сохранено в Venus_dataset/images/20180403_140445_160444
# Обработана пара: 20180403_180443_200445.flo, сохранено в Venus_dataset/images/20180403_180443_200445
# Обработана пара: 20180404_104444_124446.flo, сохранено в Venus_dataset/images/20180404_104444_124446
# Обработана пара: 20180404_124446_144445.flo, сохранено в Venus_dataset/images/20180404_124446_144445
# Обработана пара: 20180404_144445_164445.flo, сохранено в Venus_dataset/images/20180404_144445_164445
# Обработана пара: 20180404_164445_184445.flo, сохранено в Venus_dataset/images/20180404_164445_184445
# Обработана пара: 20180404_184445_204443.flo, сохранено в Venus_dataset/images/20180404_184445_204443
# Обработана пара: 20180404_204443_224445.flo, сохранено в Venus_dataset/images/20180404_204443_224445
# Обработана пара: 20180405_124443_144446.flo, сохранено в Venus_dataset/images/20180405_124443_144446
# Обработана пара: 20180405_164444_184445.flo, сохранено в Venus_dataset/images/20180405_164444_184445
# Обработана пара: 20180405_184445_204446.flo, сохранено в Venus_dataset/images/20180405_184445_204446
# Обработана пара: 20180405_204446_224444.flo, сохранено в Venus_dataset/images/20180405_204446_224444
# Обработана пара: 20180406_104946_124944.flo, сохранено в Venus_dataset/images/20180406_104946_124944
# Обработана пара: 20180406_124944_144946.flo, сохранено в Venus_dataset/images/20180406_124944_144946
# Обработана пара: 20180406_144946_164945.flo, сохранено в Venus_dataset/images/20180406_144946_164945
# Обработана пара: 20180406_164945_184944.flo, сохранено в Venus_dataset/images/20180406_164945_184944
# Обработана пара: 20180406_184944_204945.flo, сохранено в Venus_dataset/images/20180406_184944_204945
# Обработана пара: 20180407_080445_100445.flo, сохранено в Venus_dataset/images/20180407_080445_100445
# Обработана пара: 20180407_100445_120445.flo, сохранено в Venus_dataset/images/20180407_100445_120445
# Обработана пара: 20180407_120445_140444.flo, сохранено в Venus_dataset/images/20180407_120445_140444
# Обработана пара: 20180407_140444_160445.flo, сохранено в Venus_dataset/images/20180407_140444_160445
# Обработана пара: 20180407_160445_180446.flo, сохранено в Venus_dataset/images/20180407_160445_180446
# Обработана пара: 20180407_180446_200443.flo, сохранено в Venus_dataset/images/20180407_180446_200443
# Обработана пара: 20180407_200443_220446.flo, сохранено в Venus_dataset/images/20180407_200443_220446
# Обработана пара: 20180408_090446_110444.flo, сохранено в Venus_dataset/images/20180408_090446_110444
# Обработана пара: 20180408_110444_130447.flo, сохранено в Venus_dataset/images/20180408_110444_130447
# Обработана пара: 20180408_130447_150445.flo, сохранено в Venus_dataset/images/20180408_130447_150445
# Обработана пара: 20180408_170445_190446.flo, сохранено в Venus_dataset/images/20180408_170445_190446
# Обработана пара: 20180408_190446_210444.flo, сохранено в Venus_dataset/images/20180408_190446_210444
# Обработана пара: 20180409_010445_030445.flo, сохранено в Venus_dataset/images/20180409_010445_030445
# Обработана пара: 20180409_030445_050447.flo, сохранено в Venus_dataset/images/20180409_030445_050447
# Обработана пара: 20180409_050447_070445.flo, сохранено в Venus_dataset/images/20180409_050447_070445
# Обработана пара: 20180409_070445_090445.flo, сохранено в Venus_dataset/images/20180409_070445_090445
# Обработана пара: 20180409_090445_110446.flo, сохранено в Venus_dataset/images/20180409_090445_110446
# Обработана пара: 20180409_110446_130444.flo, сохранено в Venus_dataset/images/20180409_110446_130444
# Обработана пара: 20180409_130444_150446.flo, сохранено в Venus_dataset/images/20180409_130444_150446
# Обработана пара: 20180409_150446_170444.flo, сохранено в Venus_dataset/images/20180409_150446_170444
# Обработана пара: 20180409_170444_190446.flo, сохранено в Venus_dataset/images/20180409_170444_190446
# Обработана пара: 20180409_190446_210446.flo, сохранено в Venus_dataset/images/20180409_190446_210446
# Обработана пара: 20180409_210446_230444.flo, сохранено в Venus_dataset/images/20180409_210446_230444
# Обработана пара: 20180410_120446_140444.flo, сохранено в Venus_dataset/images/20180410_120446_140444
# Обработана пара: 20180410_140444_160446.flo, сохранено в Venus_dataset/images/20180410_140444_160446
# Обработана пара: 20180410_160446_180444.flo, сохранено в Venus_dataset/images/20180410_160446_180444
# Обработана пара: 20180410_200445_220446.flo, сохранено в Venus_dataset/images/20180410_200445_220446
# Обработана пара: 20180411_000444_020446.flo, сохранено в Venus_dataset/images/20180411_000444_020446
# Обработана пара: 20180411_060445_080446.flo, сохранено в Venus_dataset/images/20180411_060445_080446
# Обработана пара: 20180411_080446_100443.flo, сохранено в Venus_dataset/images/20180411_080446_100443
# Обработана пара: 20180411_100443_120445.flo, сохранено в Venus_dataset/images/20180411_100443_120445
# Обработана пара: 20180411_160444_180446.flo, сохранено в Venus_dataset/images/20180411_160444_180446
# Обработана пара: 20180411_180446_200444.flo, сохранено в Venus_dataset/images/20180411_180446_200444
# Обработана пара: 20180411_200444_220445.flo, сохранено в Venus_dataset/images/20180411_200444_220445
# Обработана пара: 20180412_120444_140446.flo, сохранено в Venus_dataset/images/20180412_120444_140446
# Обработана пара: 20180412_140446_160444.flo, сохранено в Venus_dataset/images/20180412_140446_160444
# Обработана пара: 20180412_160444_180445.flo, сохранено в Venus_dataset/images/20180412_160444_180445
# Обработана пара: 20180412_180445_200446.flo, сохранено в Venus_dataset/images/20180412_180445_200446
# Обработана пара: 20180412_200446_220443.flo, сохранено в Venus_dataset/images/20180412_200446_220443
# Обработана пара: 20180413_110445_130444.flo, сохранено в Venus_dataset/images/20180413_110445_130444
# Обработана пара: 20180413_130444_150446.flo, сохранено в Venus_dataset/images/20180413_130444_150446
# Обработана пара: 20180413_150446_170446.flo, сохранено в Venus_dataset/images/20180413_150446_170446
# Обработана пара: 20180413_170446_190444.flo, сохранено в Venus_dataset/images/20180413_170446_190444
# Обработана пара: 20180413_190444_210446.flo, сохранено в Venus_dataset/images/20180413_190444_210446
# Обработана пара: 20180414_080446_100445.flo, сохранено в Venus_dataset/images/20180414_080446_100445
# Обработана пара: 20180414_100445_120446.flo, сохранено в Venus_dataset/images/20180414_100445_120446
# Обработана пара: 20180414_120446_140446.flo, сохранено в Venus_dataset/images/20180414_120446_140446
# Обработана пара: 20180414_140446_160444.flo, сохранено в Venus_dataset/images/20180414_140446_160444
# Обработана пара: 20180414_160444_180446.flo, сохранено в Venus_dataset/images/20180414_160444_180446
# Обработана пара: 20180414_180446_200444.flo, сохранено в Venus_dataset/images/20180414_180446_200444
# Обработана пара: 20180414_200444_220446.flo, сохранено в Venus_dataset/images/20180414_200444_220446
# Обработана пара: 20180415_130444_150446.flo, сохранено в Venus_dataset/images/20180415_130444_150446
# Обработана пара: 20180415_170445_190446.flo, сохранено в Venus_dataset/images/20180415_170445_190446
